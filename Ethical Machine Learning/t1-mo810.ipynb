# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("/content/drive/MyDrive/Colab files/mo810/descricaodados.csv")
dados.rename(columns={"column_name": "Nome da Variável", "data_type": "Tipo", "description": "Descrição"}, inplace=True)
dados.head(10)
# Out:
#    Nome da Variável     Tipo                      Descrição
# 0               ano    INT64                            Ano
# 1          sigla_uf   STRING  Sigla da Unidade da Federação
# 2  sequencial_obito   STRING            Sequencial do Óbito
# 3        tipo_obito   STRING                  Tipo do Óbito
# 4      causa_basica   STRING          Causa Básica (CID-10)
# 5        data_obito     DATE                  Data do Óbito
# 6        hora_obito     TIME                  Hora do Óbito
# 7      naturalidade   STRING                   Naturalidade
# 8   data_nascimento     DATE             Data de Nascimento
# 9             idade  FLOAT64                          Idade

# %%
dados.tail(10)
# Out:
#            Nome da Variável    Tipo  \
# 82           versao_sistema  STRING
# 83               versao_scb  STRING
# 84                 atestado  STRING
# 85  numero_dias_obito_ficha   INT64
# 86                   fontes  STRING
# 87  tipo_resgate_informacao  STRING
# 88  tipo_nivel_investigador  STRING
# 89   numero_dias_informacao   INT64
# 90        fontes_informacao  STRING
# 91                alt_causa  STRING
#
#                                             Descrição
# 82                                  Versão do Sistema
# 83                  Versão do Seletor de Causa Básica
# 84                        CIDs Informados no Atestado
# 85  Número de Dias Entre a Data do Óbito e a Data ...
# 86                                             Fontes
# 87  A Investigação Permitiu o Resgate de Alguma Ca...
# 88                         Tipo de Nível Investigador
# 89                          Número de Dias Informação
# 90                                  Fontes Informação
# ...

# %%
dados.to_csv("dadosdescritos.csv")
